# %%
from PIL import ImageDraw, Image, ImageFont
fnt = ImageFont.truetype('Pillow/Tests/fonts/FreeMono.ttf', 40)

image = Image.open("images/githubexample.png")
image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=2001x1002 at 0x7F1C31F69278>

# %%
cimage = image.copy()
ImageDraw.Draw(cimage).rectangle((10, 27, 352, 82), outline=255, width=5)
cimage
# Out:
# <PIL.Image.Image image mode=RGB size=2001x1002 at 0x7F1C310B6470>

# %%
cimage.save("images/githubexample1.png")

# %%
cimage = image.copy()
ImageDraw.Draw(cimage).rectangle((1316, 12, 1990, 96), outline=255, width=5)
cimage
# Out:
# <PIL.Image.Image image mode=RGB size=2001x1002 at 0x7F1C1E4A10F0>

# %%
cimage.save("images/githubexample2.png")

# %%
cimage = image.copy()
ImageDraw.Draw(cimage).rectangle((192, 128, 672, 186), outline=255, width=5)
cimage
# Out:
# <PIL.Image.Image image mode=RGB size=2001x1002 at 0x7F1C1E4A1EB8>

# %%
cimage.save("images/githubexample3.png")

# %%
cimage = image.copy()
ImageDraw.Draw(cimage).rectangle((90, 382, 1864, 444), outline=255, width=5)
cimage
# Out:
# <PIL.Image.Image image mode=RGB size=2001x1002 at 0x7F1C1DD39B00>

# %%
cimage.save("images/githubexample4.png")

# %%
cimage = image.copy()
ImageDraw.Draw(cimage).rectangle((28, 678, 190, 994), outline=255, width=5)
cimage
# Out:
# <PIL.Image.Image image mode=RGB size=2001x1002 at 0x7F1C1E4A1F98>

# %%
cimage.save("images/githubexample5.png")

# %%
cimage = image.copy()
ImageDraw.Draw(cimage).rectangle((345, 678, 1972, 994), outline=255, width=5)
cimage
# Out:
# <PIL.Image.Image image mode=RGB size=2001x1002 at 0x7F1C1E4AA438>

# %%
cimage.save("images/githubexample6.png")

# %%
cimage = Image.open("images/inspect.png")
fnt = ImageFont.truetype('Pillow/Tests/fonts/FreeMono.ttf', 40)
draw = ImageDraw.Draw(cimage)
draw.text((5, 186), "1", font=fnt, fill=(255, 0, 0))
draw.rectangle((2, 226, 66, 280), outline=255, width=5)
draw.text((1713, 152), "2", font=fnt, fill=(255, 0, 0))
draw.rectangle((1710, 92, 1779, 148), outline=255, width=5)
draw.text((100, 430), "3", font=fnt, fill=(255, 0, 0))
draw.rectangle((126, 470, 165, 508), outline=255, width=5)
draw.text((258, 430), "4", font=fnt, fill=(255, 0, 0))
draw.rectangle((255, 470, 630, 508), outline=255, width=5)
cimage
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=2023x874 at 0x7F1C1E50E940>

# %%
cimage.save("images/inspectmarked.png")
